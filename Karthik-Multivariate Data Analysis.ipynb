# %%
import pandas as pd

# %%
df = pd.read_excel('HBAT.xlsx')
df.head()
# Out:
#    id  x1  x2  x3  x4  x5   x6   x7   x8   x9  ...  x14  x15  x16  x17  x18  \
# 0   1   2   0   1   1   1  8.5  3.9  2.5  5.9  ...  4.7  4.3  5.0  5.1  3.7
# 1   2   3   1   0   0   0  8.2  2.7  5.1  7.2  ...  5.5  4.0  3.9  4.3  4.9
# 2   3   3   0   1   1   1  9.2  3.4  5.6  5.6  ...  6.2  4.6  5.4  4.0  4.5
# 3   4   1   1   1   1   0  6.4  3.3  7.0  3.7  ...  7.0  3.6  4.3  4.1  3.0
# 4   5   2   0   1   0   1  9.0  3.4  5.2  4.6  ...  6.1  4.5  4.5  3.5  3.5
#
#    x19  x20  x21   x22  x23
# 0  8.2  8.0  8.4  65.1    1
# 1  5.7  6.5  7.5  67.1    0
# 2  8.9  8.4  9.0  72.1    1
# 3  4.8  6.0  7.2  40.1    0
# 4  7.1  6.6  9.0  57.1    0
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (100, 24)

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['x6'], color='blue', edgecolor='black')

plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram of {}'.format('x6'))
# Out:
# Text(0.5, 1.0, 'Histogram of x6')

# %%
plt.hist(df['x7'], color='blue', edgecolor='black')

plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram of {}'.format('x7'))
# Out:
# Text(0.5, 1.0, 'Histogram of x7')

# %%
plt.hist(df['x16'], color='blue', edgecolor='black')

plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram of {}'.format('x16'))
# Out:
# Text(0.5, 1.0, 'Histogram of x16')

# %%
plt.hist(df['x17'], color='blue', edgecolor='black')

plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram of {}'.format('x17'))
# Out:
# Text(0.5, 1.0, 'Histogram of x17')

# %%
from scipy.stats import shapiro

# %%
statistic, p_value = shapiro(df['x6'])

print("Shapiro-Wilk Test Statistic:", statistic)
print("p-value:", p_value)

# Interpret the results
alpha = 0.05
if p_value > alpha:
    print("Sample looks Gaussian (fail to reject H0)")
else:
    print("Sample does not look Gaussian and it is not normal (reject H0)")

#Skewness
skewness_x6 = df['x6'].skew()

#Kurtosis
kurtosis_x6 = df['x6'].kurtosis()

# Print the results
print("Skewness of variable x6 is:", skewness_x6)
print("Kurtosis of variable x6 is:", kurtosis_x6)
# Out:
# Shapiro-Wilk Test Statistic: 0.9497218728065491
# p-value: 0.0007953463937155902
# Sample does not look Gaussian and it is not normal (reject H0)
# Skewness of variable x6 is: -0.2445018700209238
# Kurtosis of variable x6 is: -1.1318375092066733

# %%
statistic, p_value = shapiro(df['x7'])

print("Shapiro-Wilk Test Statistic:", statistic)
print("p-value:", p_value)

# Interpret the results
alpha = 0.05
if p_value > alpha:
    print("Sample looks Gaussian (fail to reject H0)")
else:
    print("Sample does not look Gaussian and it is not normal (reject H0)")

#Skewness
skewness_x7 = df['x7'].skew()

#Kurtosis
kurtosis_x7 = df['x7'].kurtosis()

# Print the results
print("Skewness of variable x7 is:", skewness_x7)
print("Kurtosis of variable x7 is:", kurtosis_x7)
# Out:
# Shapiro-Wilk Test Statistic: 0.9585165977478027
# p-value: 0.0031565006356686354
# Sample does not look Gaussian and it is not normal (reject H0)
# Skewness of variable x7 is: 0.6603903156570311
# Kurtosis of variable x7 is: 0.7353469653961473

# %%
statistic, p_value = shapiro(df['x16'])

print("Shapiro-Wilk Test Statistic:", statistic)
print("p-value:", p_value)

# Interpret the results
alpha = 0.05
if p_value > alpha:
    print("Sample looks Gaussian (fail to reject H0)")
else:
    print("Sample does not look Gaussian and it is not normal (reject H0)")

#Skewness
skewness_x16 = df['x16'].skew()

#Kurtosis
kurtosis_x16 = df['x16'].kurtosis()

# Print the results
print("Skewness of variable x16 is:", skewness_x16)
print("Kurtosis of variable x16 is:", kurtosis_x16)
# Out:
# Shapiro-Wilk Test Statistic: 0.9740519523620605
# p-value: 0.04549388214945793
# Sample does not look Gaussian and it is not normal (reject H0)
# Skewness of variable x16 is: -0.3335403573026519
# Kurtosis of variable x16 is: 0.2441490942473128

# %%
statistic, p_value = shapiro(df['x17'])

print("Shapiro-Wilk Test Statistic:", statistic)
print("p-value:", p_value)

# Interpret the results
alpha = 0.05
if p_value > alpha:
    print("Sample looks Gaussian (fail to reject H0)")
else:
    print("Sample does not look Gaussian and it is not normal (reject H0)")

#Skewness
skewness_x17 = df['x17'].skew()

#Kurtosis
kurtosis_x17 = df['x17'].kurtosis()

# Print the results
print("Skewness of variable x17 is:", skewness_x17)
print("Kurtosis of variable x17 is:", kurtosis_x17)
# Out:
# Shapiro-Wilk Test Statistic: 0.9654566645622253
# p-value: 0.010037846863269806
# Sample does not look Gaussian and it is not normal (reject H0)
# Skewness of variable x17 is: 0.32276645434314727
# Kurtosis of variable x17 is: -0.8158664724164599

# %%
import seaborn as sns
variables = ['x6', 'x7', 'x16', 'x17']
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 8))
axes = axes.flatten()
for i, var in enumerate(variables):
    sns.kdeplot(df[var], ax=axes[i], color='blue', fill=True)
    axes[i].set_title('Density Plot of {}'.format(var))
    axes[i].set_xlabel(var)
    axes[i].set_ylabel('Density')
plt.tight_layout()
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt
variables = ['x6', 'x7', 'x16', 'x17']
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 8))
axes = axes.flatten()
for i, var in enumerate(variables):
    stats.probplot(df[var], plot=axes[i], fit=True)
    axes[i].set_title('Normal Probability Plot of {}'.format(var))
    axes[i].set_xlabel('Theoretical Quantiles')
    axes[i].set_ylabel('Ordered Values')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Ellipse

# Set up the subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Scatterplot of X7 versus X19
sns.scatterplot(x='x7', y='x19', data=df, ax=axes[0])
sns.scatterplot(x='x6', y='x19', data=df, ax=axes[1])


mean_X7_X19 = df[['x7', 'x19']].mean().values
cov_X7_X19 = np.cov(df[['x7', 'x19']].values, rowvar=False)

mean_X6_X19 = df[['x6', 'x19']].mean().values
cov_X6_X19 = np.cov(df[['x6', 'x19']].values, rowvar=False)


ellipse_X7_X19 = Ellipse(xy=mean_X7_X19, width=2 * np.sqrt(5.991 * cov_X7_X19[0, 0]), 
                         height=2 * np.sqrt(5.991 * cov_X7_X19[1, 1]), 
                         angle=np.rad2deg(np.arccos(cov_X7_X19[0, 1] / np.sqrt(cov_X7_X19[0, 0] * cov_X7_X19[1, 1]))), 
                         edgecolor='red', fc='None')
ellipse_X6_X19 = Ellipse(xy=mean_X6_X19, width=2 * np.sqrt(5.991 * cov_X6_X19[0, 0]), 
                         height=2 * np.sqrt(5.991 * cov_X6_X19[1, 1]), 
                         angle=np.rad2deg(np.arccos(cov_X6_X19[0, 1] / np.sqrt(cov_X6_X19[0, 0] * cov_X6_X19[1, 1]))), 
                         edgecolor='red', fc='None')


axes[0].add_patch(ellipse_X7_X19)
axes[1].add_patch(ellipse_X6_X19)


axes[0].set_title('Scatterplot of X7 vs X19')
axes[1].set_title('Scatterplot of X6 vs X19')


plt.tight_layout()
plt.show()

# %%
variables = ['x6', 'x7', 'x8', 'x12']
corr_matrix = df[variables].corr()
sns.heatmap(corr_matrix, annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(18, 10))


sns.boxplot(x='x6', y='x1', data=df)
plt.title('Boxplot of X6 with X1')

plt.show()

# %%
plt.figure(figsize=(27, 10))


sns.boxplot(x='x7', y='x1', data=df)
plt.title('Boxplot of X7 with X1')

plt.show()

# %%
# Calculate the interquartile range (IQR) for X6
Q1_X6 = df['x6'].quantile(0.25)
Q3_X6 = df['x6'].quantile(0.75)
IQR_X6 = Q3_X6 - Q1_X6

# Calculate the lower and upper bounds for outliers
lower_bound_X6 = Q1_X6 - 1.5 * IQR_X6
upper_bound_X6 = Q3_X6 + 1.5 * IQR_X6

# Find outliers in X6
outliers_X6 = df[(df['x6'] < lower_bound_X6) | (df['x6'] > upper_bound_X6)]

# Calculate the interquartile range (IQR) for X1
Q1_X1 = df['x1'].quantile(0.25)
Q3_X1 = df['x1'].quantile(0.75)
IQR_X1 = Q3_X1 - Q1_X1

# Calculate the lower and upper bounds for outliers
lower_bound_X1 = Q1_X1 - 1.5 * IQR_X1
upper_bound_X1 = Q3_X1 + 1.5 * IQR_X1

# Find outliers in X1
outliers_X1 = df[(df['x1'] < lower_bound_X1) | (df['x1'] > upper_bound_X1)]

print("Outliers in X6:")
print(outliers_X6)

print("\nOutliers in X1:")
print(outliers_X1)
# Out:
# Outliers in X6:
# Empty DataFrame
# Columns: [id, x1, x2, x3, x4, x5, x6, x7, x8, x9, x10, x11, x12, x13, x14, x15, x16, x17, x18, x19, x20, x21, x22, x23]
# Index: []
#
# [0 rows x 24 columns]
#
# Outliers in X1:
# Empty DataFrame
# Columns: [id, x1, x2, x3, x4, x5, x6, x7, x8, x9, x10, x11, x12, x13, x14, x15, x16, x17, x18, x19, x20, x21, x22, x23]
# Index: []
#
# [0 rows x 24 columns]

# %%
# Calculate the interquartile range (IQR) for X7
Q1_X7 = df['x7'].quantile(0.25)
Q3_X7 = df['x7'].quantile(0.75)
IQR_X7 = Q3_X7 - Q1_X7

# Calculate the lower and upper bounds for outliers
lower_bound_X7 = Q1_X7 - 1.5 * IQR_X7
upper_bound_X7 = Q3_X7 + 1.5 * IQR_X7

# Find outliers in X7
outliers_X7 = df[(df['x7'] < lower_bound_X7) | (df['x7'] > upper_bound_X7)]

# Calculate the interquartile range (IQR) for X1
Q1_X1 = df['x1'].quantile(0.25)
Q3_X1 = df['x1'].quantile(0.75)
IQR_X1 = Q3_X1 - Q1_X1

# Calculate the lower and upper bounds for outliers
lower_bound_X1 = Q1_X1 - 1.5 * IQR_X1
upper_bound_X1 = Q3_X1 + 1.5 * IQR_X1

# Find outliers in X1
outliers_X1 = df[(df['x1'] < lower_bound_X1) | (df['x1'] > upper_bound_X1)]

print("Outliers in X7:")
print(outliers_X7)

print("\nOutliers in X1:")
print(outliers_X1)
# Out:
# Outliers in X7:
#     id  x1  x2  x3  x4  x5   x6   x7   x8   x9  ...  x14  x15  x16  x17  x18  \
# 11  12   1   0   1   1   0  6.1  4.9  6.3  3.9  ...  5.8  5.9  3.0  4.9  3.2
# 12  13   1   1   0   0   1  9.5  5.6  4.6  6.9  ...  6.5  5.3  5.1  4.5  4.4
# 21  22   3   1   1   1   1  9.6  5.7  6.8  5.9  ...  6.4  6.5  4.3  3.0  4.3
# 39  40   1   0   0   1   0  6.1  4.9  3.0  4.8  ...  5.1  6.8  4.5  4.9  3.2
# 42  43   3   0   1   0   1  9.3  5.1  4.6  6.8  ...  5.1  4.1  4.6  4.6  4.3
# 43  44   2   1   1   1   1  5.1  5.1  6.6  6.9  ...  7.2  5.2  4.9  6.3  4.5
# 56  57   2   0   1   1   1  7.4  5.1  4.8  7.7  ...  6.4  7.4  5.7  6.5  5.5
# 63  64   1   0   1   1   0  7.7  2.2  6.3  4.5  ...  6.0  4.7  3.3  3.1  2.6
# 89  90   2   1   0   1   1  5.5  5.5  7.7  7.0  ...  7.4  4.9  5.5  6.7  4.9
# 98  99   2   1   0   1   1  7.8  4.9  5.8  5.3  ...  6.0  5.7  4.3  4.9  3.9
#
#     x19  x20  x21   x22  x23
# 11  6.0  6.3  6.6  53.1    0
# 12  8.4  8.4  7.9  58.1    1
# ...

# %%
df1 = pd.read_excel('Hand drawn histogram sheet.xlsx')

# %%
df1
# Out:
#      X1   X2
# 0   3.9  2.5
# 1   2.7  5.1
# 2   3.4  5.6
# 3   3.3  7.0
# 4   3.4  5.2
# 5   2.8  3.1
# 6   3.7  5.0
# 7   3.3  3.9
# 8   3.6  5.1
# 9   4.5  5.1
# 10  3.2  4.6
# 11  4.9  6.3
# 12  5.6  4.6
# 13  3.9  5.7
# 14  4.5  4.7

# %%
sns.histplot(df1['X1'])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='X1', ylabel='Count'>

# %%
sns.histplot(df1['X2'])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='X2', ylabel='Count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create the scatter plot
sns.scatterplot(x=df1['X1'], y=df1['X2'])

# Add title and labels
plt.title('Scatter Plot of X1 vs X2')
plt.xlabel('X1 values')
plt.ylabel('X2 values')

# Show the plot
plt.show()

# %%
df1['X1'].skew()
# Out:
# 0.8886041799155819

# %%
df1['X2'].skew()
# Out:
# -0.4435134690747855

# %%
df1['X1'].skew()----0.8886041799155819
df1['X2'].skew()------0.4435134690747855
